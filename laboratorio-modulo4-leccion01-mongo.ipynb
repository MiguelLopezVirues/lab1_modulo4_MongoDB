# %% [markdown]
# <div style="text-align: center;">
#   <img src="https://github.com/Hack-io-Data/Imagenes/blob/main/01-LogosHackio/logo_naranja@4x.png?raw=true" alt="esquema" />
# </div>
#
# # Contexto
#
# Trabajas como analista de datos para una empresa de comercio electrónico que vende una variedad de productos, desde libros y electrónicos hasta ropa y alimentos. Tu empresa está expandiendo sus operaciones y necesita optimizar la gestión de campañas de marketing y la interacción con los clientes. Para ello, has decidido utilizar MongoDB para almacenar y analizar los datos relacionados con los locales de la empresa, los productos, los clientes y las campañas de marketing.
#
# #### Ejercicio 1. Creación de la BBDD y colecciones.
#
# - 1.1. Carga el archivo json 'campaigns.json'
#
# - 1.2. Crea una base de datos llamada EcommerceDB.
#
# - 1.3. Crea las colecciones asociadas a ese archivo json.
#
# - 1.4. Inserta los datos a las distintas colecciones

# %%
# importamos las librerías que necesitamos

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Para trabajar con datos de tipo fecha
# ------------------------------------------------------------------------------
from datetime import datetime

# Para trabajar con Mongo
# ------------------------------------------------------------------------------
import pymongo

# Para utilizar nuestras funciones
# ------------------------------------------------------------------------------
# from src import soporte_mongo as sm

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %%
# lo primero que tenemos que hacer es conectarnos con Mongo
cliente = pymongo.MongoClient()
print(cliente)

# como la conexión se ha realizado con éxito vamos a ver las bases de datos que tenemos
cliente.list_database_names()
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)
# ['Airbnb', 'EcommerceDB', 'admin', 'config', 'local']

# %%
# nos conectamos con una BBDD 
ecommerce_Db = cliente['EcommerceDB']

#Veamos además las colecciones de la BBDD, usando el método 'list_collection_names()'
ecommerce_Db.list_collection_names()
# Out:
# ['Campaigns']

# %%
campaigns = ecommerce_Db['Campaigns']

# %%
resultado_find_campaigns = list(campaigns.find())

# %%
resultado_find_campaigns
# Out:
# [{'_id': ObjectId('671626c8431f6a2d71991cb4'),
#   'Premises': [{'premise_id': 1,
#     'premises_type': 'Warehouse',
#     'premise_details': '036 Lueilwitz Harbor'},
#    {'premise_id': 2,
#     'premises_type': 'Warehouse',
#     'premise_details': '676 Kelly Spur'},
#    {'premise_id': 3,
#     'premises_type': 'Residence',
#     'premise_details': '27839 Carissa Tunnel Suite 048'},
#    {'premise_id': 4,
#     'premises_type': 'Residence',
#     'premise_details': '2219 Barrows Tunnel Apt. 893'},
#    {'premise_id': 5,
#     'premises_type': 'Office',
#     'premise_details': '38291 Jerde Light Apt. 713'},
#    {'premise_id': 6,
#     'premises_type': 'Office',
#     'premise_details': '5585 Abbott Walk'},
#    {'premise_id': 7,
#     'premises_type': 'Residence',
#     'premise_details': '5510 Veum Green'},
#    {'premise_id': 8,
#     'premises_type': 'Warehouse',
#     'premise_details': '7230 Tillman Glens Suite 202'},
#    {'premise_id': 9,
#     'premises_type': 'Warehouse',
#     'premise_details': '62282 Wiza Glen Apt. 430'},
#    {'premise_id': 10,
#     'premises_type': 'Office',
#     'premise_details': '07318 Annetta Motorway'},
#    {'premise_id': 11,
#     'premises_type': 'Office',
#     'premise_details': '00100 Green Mountains Apt. 653'},
#    {'premise_id': 12,
#     'premises_type': 'Office',
#     'premise_details': '33294 William Lodge Apt. 953'},
#    {'premise_id': 13,
#     'premises_type': 'Office',
#     'premise_details': '2760 Austin Station'},
#    {'premise_id': 14,
#     'premises_type': 'Residence',
#     'premise_details': '5109 Jules Squares Apt. 082'},
#    {'premise_id': 15,
#     'premises_type': 'Office',
#     'premise_details': '867 Emard Drives Apt. 066'}],
#   'Products': [{'product_id': 1,
#     'product_category': 'Food',
#     'product_name': 'Coffee Bean'},
#    {'product_id': 2,
#     'product_category': 'Electronics',
#     'product_name': 'Keyboard'},
#    {'product_id': 3,
#     'product_category': 'Books',
#     'product_name': 'Four Seasons'},
#    {'product_id': 4, 'product_category': 'Hardware', 'product_name': 'Mouse'},
#    {'product_id': 5,
#     'product_category': 'Books',
#     'product_name': 'Life of Van gogh'},
#    {'product_id': 6,
#     'product_category': 'Hardware',
#     'product_name': 'Monitor'},
#    {'product_id': 7, 'product_category': 'Electronics', 'product_name': 'MP3'},
#    {'product_id': 8,
#     'product_category': 'Books',
#     'product_name': 'Learning French'},
#    {'product_id': 9,
#     'product_category': 'Books',
#     'product_name': 'How to read a book'},
#    {'product_id': 10,
#     'product_category': 'Electronics',
#     'product_name': 'iWatch'},
#    {'product_id': 11,
#     'product_category': 'Books',
#     'product_name': 'IOS Programming'},
#    {'product_id': 12,
#     'product_category': 'Books',
#     'product_name': 'Everything about Amazon'},
#    {'product_id': 13, 'product_category': 'Hardware', 'product_name': 'Drive'},
#    {'product_id': 14, 'product_category': 'Food', 'product_name': 'Chocolate'},
#    {'product_id': 15,
#     'product_category': 'Electronics',
#     'product_name': 'iPhone'}],
#   'Customers': [{'customer_id': 1,
#     'payment_method': 'Credit Card',
#     'customer_name': 'Wendell',
#     'customer_phone': '(773)971-9411x759',
#     'customer_email': 'rodriguez.nathanael@example.net',
#     'customer_address': '618 Webster Stream Apt. 161',
#     'customer_password': 'b4459ad261'},
#    {'customer_id': 2,
#     'payment_method': 'Direct Debit',
#     'customer_name': 'Gage',
#     'customer_phone': '(402)890-2603x6005',
#     'customer_email': 'stark.elna@example.net',
#     'customer_address': '0260 Walker Trace',
#     'customer_password': '7905d7f1b1'},
#    {'customer_id': 3,
#     'payment_method': 'Direct Debit',
#     'customer_name': 'Elvera',
#     'customer_phone': '1-878-600-7193x8180',
#     'customer_email': 'madyson.mclaughlin@example.org',
#     'customer_address': '280 Landen Lake',
#     'customer_password': '0b9f651030'},
#    {'customer_id': 4,
#     'payment_method': 'Direct Debit',
#     'customer_name': 'Stella',
#     'customer_phone': '+43(3)1861877192',
#     'customer_email': 'kristina85@example.org',
#     'customer_address': '5607 Ryann Canyon',
#     'customer_password': 'f64f0fd096'},
#    {'customer_id': 5,
#     'payment_method': 'Credit Card',
#     'customer_name': 'Magdalena',
#     'customer_phone': '1-352-291-1721x265',
#     'customer_email': 'franecki.danial@example.com',
#     'customer_address': '523 Mose Hills',
#     'customer_password': 'bdfdc8e91a'},
#    {'customer_id': 6,
#     'payment_method': 'Direct Debit',
#     'customer_name': 'Carlotta',
#     'customer_phone': '+66(7)1491041398',
#     'customer_email': 'fstanton@example.net',
#     'customer_address': '31932 Kailey Lodge',
#     'customer_password': 'a8467590fd'},
#    {'customer_id': 7,
#     'payment_method': 'Direct Debit',
#     'customer_name': 'Leanna',
#     'customer_phone': '203-036-0511x96487',
#     'customer_email': 'marc.schiller@example.com',
#     'customer_address': '94105 Bahringer Oval Suite 178',
#     'customer_password': '67e9037197'},
#    {'customer_id': 8,
#     'payment_method': 'Direct Debit',
#     'customer_name': 'Ruthie',
#     'customer_phone': '(840)754-4148x20545',
#     'customer_email': 'elva.mccullough@example.org',
#     'customer_address': '5514 Ophelia Cliffs Apt. 266',
#     'customer_password': '280160b7b3'},
#    {'customer_id': 9,
#     'payment_method': 'Credit Card',
#     'customer_name': 'Donnie',
#     'customer_phone': '(030)521-0681x0191',
#     'customer_email': 'saul30@example.net',
#     'customer_address': '115 Farrell Squares Suite 599',
#     'customer_password': '22dc8bfaf5'},
#    {'customer_id': 10,
#     'payment_method': 'Direct Debit',
#     'customer_name': 'Shanel',
#     'customer_phone': '1-957-676-9414',
#     'customer_email': 'kheathcote@example.org',
#     'customer_address': '80569 Crona Path Suite 165',
#     'customer_password': 'd93857e0c2'},
#    {'customer_id': 11,
#     'payment_method': 'Direct Debit',
#     'customer_name': 'Osborne',
#     'customer_phone': '232.171.7032',
#     'customer_email': 'vpowlowski@example.net',
#     'customer_address': '509 Isabelle Route',
#     'customer_password': 'b00e35cc0a'},
#    {'customer_id': 12,
#     'payment_method': 'Direct Debit',
#     'customer_name': 'Kyle',
#     'customer_phone': '291-425-7193',
#     'customer_email': 'davis.rosamond@example.net',
#     'customer_address': '056 Ibrahim Path Suite 669',
#     'customer_password': '341f672c2c'},
#    {'customer_id': 13,
#     'payment_method': 'Credit Card',
#     'customer_name': 'Annabel',
#     'customer_phone': '100.220.3484',
#     'customer_email': 'yoshiko.balistreri@example.org',
#     'customer_address': '56955 Desmond Lake Apt. 120',
#     'customer_password': '9dc50bc5b6'},
#    {'customer_id': 14,
#     'payment_method': 'Direct Debit',
#     'customer_name': 'Geovanny',
#     'customer_phone': '205.496.0690x53058',
#     'customer_email': 'jesus.robel@example.org',
#     'customer_address': '0813 Carolina Bridge Suite 488',
#     'customer_password': '49f32173a2'},
#    {'customer_id': 15,
#     'payment_method': 'Direct Debit',
#     'customer_name': 'Mitchell',
#     'customer_phone': '698-327-5792',
#     'customer_email': 'princess75@example.com',
#     'customer_address': '6735 Daron Lane Apt. 271',
#     'customer_password': '791b1b3e64'}],
#   'Mailshot_Campaigns': [{'mailshot_id': 1,
#     'product_category': 'food',
#     'mailshot_name': 'US',
#     'mailshot_start_date': '02/15/2018',
#     'mailshot_end_date': '03/08/2018'},
#    {'mailshot_id': 2,
#     'product_category': 'clothes',
#     'mailshot_name': 'US',
#     'mailshot_start_date': '09/14/2017',
#     'mailshot_end_date': '03/15/2018'},
#    {'mailshot_id': 3,
#     'product_category': 'food',
#     'mailshot_name': 'FED',
#     'mailshot_start_date': '06/16/2017',
#     'mailshot_end_date': '03/13/2018'},
#    {'mailshot_id': 4,
#     'product_category': 'clothes',
#     'mailshot_name': 'USPS',
#     'mailshot_start_date': '09/27/2017',
#     'mailshot_end_date': '03/18/2018'},
#    {'mailshot_id': 5,
#     'product_category': 'food',
#     'mailshot_name': 'AL',
#     'mailshot_start_date': '05/20/2017',
#     'mailshot_end_date': '03/02/2018'},
#    {'mailshot_id': 6,
#     'product_category': 'clothes',
#     'mailshot_name': 'FED',
#     'mailshot_start_date': '10/23/2017',
#     'mailshot_end_date': '03/03/2018'},
#    {'mailshot_id': 7,
#     'product_category': 'food',
#     'mailshot_name': 'FED',
#     'mailshot_start_date': '11/25/2017',
#     'mailshot_end_date': '03/05/2018'},
#    {'mailshot_id': 8,
#     'product_category': 'clothes',
#     'mailshot_name': 'AL',
#     'mailshot_start_date': '10/22/2017',
#     'mailshot_end_date': '03/01/2018'},
#    {'mailshot_id': 9,
#     'product_category': 'food',
#     'mailshot_name': 'US',
#     'mailshot_start_date': '11/12/2017',
#     'mailshot_end_date': '02/27/2018'},
#    {'mailshot_id': 10,
#     'product_category': 'clothes',
#     'mailshot_name': 'USPS',
#     'mailshot_start_date': '01/14/2018',
#     'mailshot_end_date': '03/19/2018'},
#    {'mailshot_id': 11,
#     'product_category': 'food',
#     'mailshot_name': 'US',
#     'mailshot_start_date': '12/13/2017',
#     'mailshot_end_date': '03/24/2018'},
#    {'mailshot_id': 12,
#     'product_category': 'clothes',
#     'mailshot_name': 'USPS',
#     'mailshot_start_date': '01/20/2018',
#     'mailshot_end_date': '03/23/2018'},
#    {'mailshot_id': 13,
#     'product_category': 'food',
#     'mailshot_name': 'AL',
#     'mailshot_start_date': '05/08/2017',
#     'mailshot_end_date': '03/12/2018'},
#    {'mailshot_id': 14,
#     'product_category': 'clothes',
#     'mailshot_name': 'AL',
#     'mailshot_start_date': '06/11/2017',
#     'mailshot_end_date': '03/23/2018'},
#    {'mailshot_id': 15,
#     'product_category': 'food',
#     'mailshot_name': 'FED',
#     'mailshot_start_date': '11/29/2017',
#     'mailshot_end_date': '03/17/2018'},
#    {'mailshot_id': 16,
#     'product_category': 'clothes',
#     'mailshot_name': 'US',
#     'mailshot_start_date': '11/02/2017',
#     'mailshot_end_date': '03/02/2018'},
#    {'mailshot_id': 17,
#     'product_category': 'food',
#     'mailshot_name': 'FED',
#     'mailshot_start_date': '02/04/2018',
#     'mailshot_end_date': '02/26/2018'},
#    {'mailshot_id': 18,
#     'product_category': 'clothes',
#     'mailshot_name': 'USPS',
#     'mailshot_start_date': '12/08/2017',
#     'mailshot_end_date': '03/20/2018'},
#    {'mailshot_id': 19,
#     'product_category': 'food',
#     'mailshot_name': 'US',
#     'mailshot_start_date': '06/25/2017',
#     'mailshot_end_date': '03/15/2018'},
#    {'mailshot_id': 20,
#     'product_category': 'food',
#     'mailshot_name': 'US',
#     'mailshot_start_date': '11/15/2017',
#     'mailshot_end_date': '03/15/2018'}],
#   'Customer_Addresses': [{'customer_id': 15,
#     'premise_id': 1,
#     'date_address_from': '08/23/1992',
#     'address_type_code': 'Billing',
#     'date_address_to': '02/28/2018'},
#    {'customer_id': 2,
#     'premise_id': 2,
#     'date_address_from': '02/23/2010',
#     'address_type_code': 'Billing',
#     'date_address_to': '03/15/2018'},
#    {'customer_id': 1,
#     'premise_id': 1,
#     'date_address_from': '12/24/1975',
#     'address_type_code': 'Shipping',
#     'date_address_to': '03/08/2018'},
#    {'customer_id': 3,
#     'premise_id': 2,
#     'date_address_from': '03/26/1995',
#     'address_type_code': 'Shipping',
#     'date_address_to': '02/27/2018'},
#    {'customer_id': 7,
#     'premise_id': 1,
#     'date_address_from': '05/14/1929',
#     'address_type_code': 'Billing',
#     'date_address_to': '03/16/2018'},
#    {'customer_id': 8,
#     'premise_id': 4,
#     'date_address_from': '01/15/1939',
#     'address_type_code': 'Shipping',
#     'date_address_to': '03/13/2018'},
#    {'customer_id': 5,
#     'premise_id': 5,
#     'date_address_from': '03/24/1931',
#     'address_type_code': 'Shipping',
#     'date_address_to': '03/05/2018'},
#    {'customer_id': 11,
#     'premise_id': 6,
#     'date_address_from': '04/23/1975',
#     'address_type_code': 'Billing',
#     'date_address_to': '03/04/2018'},
#    {'customer_id': 11,
#     'premise_id': 3,
#     'date_address_from': '08/18/1920',
#     'address_type_code': 'Shipping',
#     'date_address_to': '03/22/2018'},
#    {'customer_id': 11,
#     'premise_id': 5,
#     'date_address_from': '07/31/1960',
#     'address_type_code': 'Shipping',
#     'date_address_to': '03/09/2018'},
#    {'customer_id': 13,
#     'premise_id': 6,
#     'date_address_from': '12/19/1990',
#     'address_type_code': 'Billing',
#     'date_address_to': '03/24/2018'},
#    {'customer_id': 4,
#     'premise_id': 8,
#     'date_address_from': '03/18/1985',
#     'address_type_code': 'Shipping',
#     'date_address_to': '02/27/2018'},
#    {'customer_id': 10,
#     'premise_id': 10,
#     'date_address_from': '06/06/1972',
#     'address_type_code': 'Billing',
#     'date_address_to': '03/08/2018'},
#    {'customer_id': 8,
#     'premise_id': 12,
#     'date_address_from': '06/16/1984',
#     'address_type_code': 'Billing',
#     'date_address_to': '03/05/2018'},
#    {'customer_id': 3,
#     'premise_id': 14,
#     'date_address_from': '02/01/2002',
#     'address_type_code': 'Billing',
#     'date_address_to': '03/16/2018'}],
#   'Customer_Orders': [{'order_id': 1,
#     'customer_id': 2,
#     'order_status_code': 'Cancelled',
#     'shipping_method_code': 'Unspecified',
#     'order_placed_datetime': '06/15/2015',
#     'order_delivered_datetime': '03/20/2018',
#     'order_shipping_charges': '85.79'},
#    {'order_id': 2,
#     'customer_id': 8,
#     'order_status_code': 'Cancelled',
#     'shipping_method_code': 'Unspecified',
#     'order_placed_datetime': '07/05/2009',
#     'order_delivered_datetime': '03/20/2018',
#     'order_shipping_charges': '98.4'},
#    {'order_id': 3,
#     'customer_id': 9,
#     'order_status_code': 'Cancelled',
#     'shipping_method_code': 'FedEx',
#     'order_placed_datetime': '11/15/2008',
#     'order_delivered_datetime': '03/20/2018',
#     'order_shipping_charges': '36.87'},
#    {'order_id': 4,
#     'customer_id': 1,
#     'order_status_code': 'Delivered',
#     'shipping_method_code': 'UPS',
#     'order_placed_datetime': '10/23/2008',
#     'order_delivered_datetime': '03/20/2018',
#     'order_shipping_charges': '98.73'},
#    {'order_id': 5,
#     'customer_id': 7,
#     'order_status_code': 'Paid',
#     'shipping_method_code': 'FedEx',
#     'order_placed_datetime': '05/28/2017',
#     'order_delivered_datetime': '03/20/2018',
#     'order_shipping_charges': '35.63'},
#    {'order_id': 6,
#     'customer_id': 2,
#     'order_status_code': 'Cancelled',
#     'shipping_method_code': 'Unspecified',
#     'order_placed_datetime': '06/24/2014',
#     'order_delivered_datetime': '03/20/2018',
#     'order_shipping_charges': '99.26'},
#    {'order_id': 7,
#     'customer_id': 15,
#     'order_status_code': 'Cancelled',
#     'shipping_method_code': 'FedEx',
#     'order_placed_datetime': '08/28/2014',
#     'order_delivered_datetime': '03/20/2018',
#     'order_shipping_charges': '26.56'},
#    {'order_id': 8,
#     'customer_id': 2,
#     'order_status_code': 'Delivered',
#     'shipping_method_code': 'Unspecified',
#     'order_placed_datetime': '06/05/2012',
#     'order_delivered_datetime': '03/20/2018',
#     'order_shipping_charges': '77.32'},
#    {'order_id': 9,
#     'customer_id': 1,
#     'order_status_code': 'Cancelled',
#     'shipping_method_code': 'FedEx',
#     'order_placed_datetime': '05/30/2009',
#     'order_delivered_datetime': '03/20/2018',
#     'order_shipping_charges': '57.36'},
#    {'order_id': 10,
#     'customer_id': 14,
#     'order_status_code': 'Paid',
#     'shipping_method_code': 'Unspecified',
#     'order_placed_datetime': '08/29/2013',
#     'order_delivered_datetime': '03/20/2018',
#     'order_shipping_charges': '33.58'},
#    {'order_id': 11,
#     'customer_id': 1,
#     'order_status_code': 'Paid',
#     'shipping_method_code': 'Unspecified',
#     'order_placed_datetime': '12/29/2015',
#     'order_delivered_datetime': '03/20/2018',
#     'order_shipping_charges': '22.84'},
#    {'order_id': 12,
#     'customer_id': 12,
#     'order_status_code': 'Cancelled',
#     'shipping_method_code': 'Unspecified',
#     'order_placed_datetime': '10/20/2016',
#     'order_delivered_datetime': '03/20/2018',
#     'order_shipping_charges': '21.24'},
#    {'order_id': 13,
#     'customer_id': 12,
#     'order_status_code': 'Paid',
#     'shipping_method_code': 'FedEx',
#     'order_placed_datetime': '06/16/2013',
#     'order_delivered_datetime': '03/20/2018',
#     'order_shipping_charges': '31.33'},
#    {'order_id': 14,
#     'customer_id': 14,
#     'order_status_code': 'Paid',
#     'shipping_method_code': 'UPS',
#     'order_placed_datetime': '04/29/2010',
#     'order_delivered_datetime': '03/20/2018',
#     'order_shipping_charges': '46.4'},
#    {'order_id': 15,
#     'customer_id': 5,
#     'order_status_code': 'Delivered',
#     'shipping_method_code': 'FedEx',
#     'order_placed_datetime': '01/18/2009',
#     'order_delivered_datetime': '03/20/2018',
#     'order_shipping_charges': '74.28'}],
#   'Mailshot_Customers': [{'mailshot_id': 4,
#     'customer_id': 3,
#     'outcome_code': 'Order',
#     'mailshot_customer_date': '03/15/2018'},
#    {'mailshot_id': 10,
#     'customer_id': 1,
#     'outcome_code': 'No Response',
#     'mailshot_customer_date': '03/04/2018'},
#    {'mailshot_id': 15,
#     'customer_id': 9,
#     'outcome_code': 'No Response',
#     'mailshot_customer_date': '03/11/2018'},
#    {'mailshot_id': 20,
#     'customer_id': 11,
#     'outcome_code': 'Order',
#     'mailshot_customer_date': '03/01/2018'},
#    {'mailshot_id': 7,
#     'customer_id': 1,
#     'outcome_code': 'Order',
#     'mailshot_customer_date': '03/13/2018'},
#    {'mailshot_id': 10,
#     'customer_id': 4,
#     'outcome_code': 'No Response',
#     'mailshot_customer_date': '03/15/2018'},
#    {'mailshot_id': 15,
#     'customer_id': 6,
#     'outcome_code': 'Order',
#     'mailshot_customer_date': '03/06/2018'},
#    {'mailshot_id': 10,
#     'customer_id': 13,
#     'outcome_code': 'Order',
#     'mailshot_customer_date': '02/26/2018'},
#    {'mailshot_id': 15,
#     'customer_id': 13,
#     'outcome_code': 'Order',
#     'mailshot_customer_date': '03/07/2018'},
#    {'mailshot_id': 17,
#     'customer_id': 11,
#     'outcome_code': 'Order',
#     'mailshot_customer_date': '03/05/2018'},
#    {'mailshot_id': 18,
#     'customer_id': 14,
#     'outcome_code': 'Order',
#     'mailshot_customer_date': '03/14/2018'},
#    {'mailshot_id': 15,
#     'customer_id': 6,
#     'outcome_code': 'Order',
#     'mailshot_customer_date': '02/27/2018'},
#    {'mailshot_id': 18,
#     'customer_id': 2,
#     'outcome_code': 'Order',
#     'mailshot_customer_date': '03/20/2018'},
#    {'mailshot_id': 7,
#     'customer_id': 1,
#     'outcome_code': 'No Response',
#     'mailshot_customer_date': '03/03/2018'},
#    {'mailshot_id': 6,
#     'customer_id': 6,
#     'outcome_code': 'No Response',
#     'mailshot_customer_date': '03/05/2018'}],
#   'Order_Items': [{'item_id': 1,
#     'order_item_status_code': 'Delivered',
#     'order_id': 10,
#     'product_id': 13,
#     'item_status_code': 'good',
#     'item_delivered_datetime': '02/25/2018',
#     'item_order_quantity': '6'},
#    {'item_id': 2,
#     'order_item_status_code': 'Paid',
#     'order_id': 6,
#     'product_id': 7,
#     'item_status_code': 'good',
#     'item_delivered_datetime': '02/27/2018',
#     'item_order_quantity': '7'},
#    {'item_id': 3,
#     'order_item_status_code': 'Cancelled',
#     'order_id': 8,
#     'product_id': 1,
#     'item_status_code': 'good',
#     'item_delivered_datetime': '03/16/2018',
#     'item_order_quantity': '4'},
#    {'item_id': 4,
#     'order_item_status_code': 'Cancelled',
#     'order_id': 13,
#     'product_id': 11,
#     'item_status_code': 'good',
#     'item_delivered_datetime': '03/04/2018',
#     'item_order_quantity': '3'},
#    {'item_id': 5,
#     'order_item_status_code': 'Paid',
#     'order_id': 11,
#     'product_id': 5,
#     'item_status_code': 'good',
#     'item_delivered_datetime': '03/07/2018',
#     'item_order_quantity': '6'},
#    {'item_id': 6,
#     'order_item_status_code': 'Delivered',
#     'order_id': 6,
#     'product_id': 10,
#     'item_status_code': 'good',
#     'item_delivered_datetime': '03/03/2018',
#     'item_order_quantity': '5'},
#    {'item_id': 7,
#     'order_item_status_code': 'Delivered',
#     'order_id': 7,
#     'product_id': 14,
#     'item_status_code': 'good',
#     'item_delivered_datetime': '03/04/2018',
#     'item_order_quantity': '6'},
#    {'item_id': 8,
#     'order_item_status_code': 'Delivered',
#     'order_id': 2,
#     'product_id': 5,
#     'item_status_code': 'good',
#     'item_delivered_datetime': '03/05/2018',
#     'item_order_quantity': '4'},
#    {'item_id': 9,
#     'order_item_status_code': 'Delivered',
#     'order_id': 6,
#     'product_id': 6,
#     'item_status_code': 'good',
#     'item_delivered_datetime': '03/22/2018',
#     'item_order_quantity': '6'},
#    {'item_id': 10,
#     'order_item_status_code': 'Cancelled',
#     'order_id': 7,
#     'product_id': 9,
#     'item_status_code': 'good',
#     'item_delivered_datetime': '03/03/2018',
#     'item_order_quantity': '2'},
#    {'item_id': 11,
#     'order_item_status_code': 'Paid',
#     'order_id': 15,
#     'product_id': 3,
#     'item_status_code': 'good',
#     'item_delivered_datetime': '03/12/2018',
#     'item_order_quantity': '1'},
#    {'item_id': 12,
#     'order_item_status_code': 'Delivered',
#     'order_id': 11,
#     'product_id': 9,
#     'item_status_code': 'good',
#     'item_delivered_datetime': '03/03/2018',
#     'item_order_quantity': '5'},
#    {'item_id': 13,
#     'order_item_status_code': 'Paid',
#     'order_id': 14,
#     'product_id': 1,
#     'item_status_code': 'good',
#     'item_delivered_datetime': '03/07/2018',
#     'item_order_quantity': '5'},
#    {'item_id': 14,
#     'order_item_status_code': 'Paid',
#     'order_id': 15,
#     'product_id': 13,
#     'item_status_code': 'good',
#     'item_delivered_datetime': '03/17/2018',
#     'item_order_quantity': '9'},
#    {'item_id': 15,
#     'order_item_status_code': 'Paid',
#     'order_id': 14,
#     'product_id': 9,
#     'item_status_code': 'good',
#     'item_delivered_datetime': '03/05/2018',
#     'item_order_quantity': '4'}]}]

# %%
import json

# %%
with open('../datos/campaigns.json', 'r') as file:
    datos = json.load(file)

datos
# Out:
# {'Premises': [{'premise_id': 1,
#    'premises_type': 'Warehouse',
#    'premise_details': '036 Lueilwitz Harbor'},
#   {'premise_id': 2,
#    'premises_type': 'Warehouse',
#    'premise_details': '676 Kelly Spur'},
#   {'premise_id': 3,
#    'premises_type': 'Residence',
#    'premise_details': '27839 Carissa Tunnel Suite 048'},
#   {'premise_id': 4,
#    'premises_type': 'Residence',
#    'premise_details': '2219 Barrows Tunnel Apt. 893'},
#   {'premise_id': 5,
#    'premises_type': 'Office',
#    'premise_details': '38291 Jerde Light Apt. 713'},
#   {'premise_id': 6,
#    'premises_type': 'Office',
#    'premise_details': '5585 Abbott Walk'},
#   {'premise_id': 7,
#    'premises_type': 'Residence',
#    'premise_details': '5510 Veum Green'},
#   {'premise_id': 8,
#    'premises_type': 'Warehouse',
#    'premise_details': '7230 Tillman Glens Suite 202'},
#   {'premise_id': 9,
#    'premises_type': 'Warehouse',
#    'premise_details': '62282 Wiza Glen Apt. 430'},
#   {'premise_id': 10,
#    'premises_type': 'Office',
#    'premise_details': '07318 Annetta Motorway'},
#   {'premise_id': 11,
#    'premises_type': 'Office',
#    'premise_details': '00100 Green Mountains Apt. 653'},
#   {'premise_id': 12,
#    'premises_type': 'Office',
#    'premise_details': '33294 William Lodge Apt. 953'},
#   {'premise_id': 13,
#    'premises_type': 'Office',
#    'premise_details': '2760 Austin Station'},
#   {'premise_id': 14,
#    'premises_type': 'Residence',
#    'premise_details': '5109 Jules Squares Apt. 082'},
#   {'premise_id': 15,
#    'premises_type': 'Office',
#    'premise_details': '867 Emard Drives Apt. 066'}],
#  'Products': [{'product_id': 1,
#    'product_category': 'Food',
#    'product_name': 'Coffee Bean'},
#   {'product_id': 2,
#    'product_category': 'Electronics',
#    'product_name': 'Keyboard'},
#   {'product_id': 3,
#    'product_category': 'Books',
#    'product_name': 'Four Seasons'},
#   {'product_id': 4, 'product_category': 'Hardware', 'product_name': 'Mouse'},
#   {'product_id': 5,
#    'product_category': 'Books',
#    'product_name': 'Life of Van gogh'},
#   {'product_id': 6, 'product_category': 'Hardware', 'product_name': 'Monitor'},
#   {'product_id': 7, 'product_category': 'Electronics', 'product_name': 'MP3'},
#   {'product_id': 8,
#    'product_category': 'Books',
#    'product_name': 'Learning French'},
#   {'product_id': 9,
#    'product_category': 'Books',
#    'product_name': 'How to read a book'},
#   {'product_id': 10,
#    'product_category': 'Electronics',
#    'product_name': 'iWatch'},
#   {'product_id': 11,
#    'product_category': 'Books',
#    'product_name': 'IOS Programming'},
#   {'product_id': 12,
#    'product_category': 'Books',
#    'product_name': 'Everything about Amazon'},
#   {'product_id': 13, 'product_category': 'Hardware', 'product_name': 'Drive'},
#   {'product_id': 14, 'product_category': 'Food', 'product_name': 'Chocolate'},
#   {'product_id': 15,
#    'product_category': 'Electronics',
#    'product_name': 'iPhone'}],
#  'Customers': [{'customer_id': 1,
#    'payment_method': 'Credit Card',
#    'customer_name': 'Wendell',
#    'customer_phone': '(773)971-9411x759',
#    'customer_email': 'rodriguez.nathanael@example.net',
#    'customer_address': '618 Webster Stream Apt. 161',
#    'customer_password': 'b4459ad261'},
#   {'customer_id': 2,
#    'payment_method': 'Direct Debit',
#    'customer_name': 'Gage',
#    'customer_phone': '(402)890-2603x6005',
#    'customer_email': 'stark.elna@example.net',
#    'customer_address': '0260 Walker Trace',
#    'customer_password': '7905d7f1b1'},
#   {'customer_id': 3,
#    'payment_method': 'Direct Debit',
#    'customer_name': 'Elvera',
#    'customer_phone': '1-878-600-7193x8180',
#    'customer_email': 'madyson.mclaughlin@example.org',
#    'customer_address': '280 Landen Lake',
#    'customer_password': '0b9f651030'},
#   {'customer_id': 4,
#    'payment_method': 'Direct Debit',
#    'customer_name': 'Stella',
#    'customer_phone': '+43(3)1861877192',
#    'customer_email': 'kristina85@example.org',
#    'customer_address': '5607 Ryann Canyon',
#    'customer_password': 'f64f0fd096'},
#   {'customer_id': 5,
#    'payment_method': 'Credit Card',
#    'customer_name': 'Magdalena',
#    'customer_phone': '1-352-291-1721x265',
#    'customer_email': 'franecki.danial@example.com',
#    'customer_address': '523 Mose Hills',
#    'customer_password': 'bdfdc8e91a'},
#   {'customer_id': 6,
#    'payment_method': 'Direct Debit',
#    'customer_name': 'Carlotta',
#    'customer_phone': '+66(7)1491041398',
#    'customer_email': 'fstanton@example.net',
#    'customer_address': '31932 Kailey Lodge',
#    'customer_password': 'a8467590fd'},
#   {'customer_id': 7,
#    'payment_method': 'Direct Debit',
#    'customer_name': 'Leanna',
#    'customer_phone': '203-036-0511x96487',
#    'customer_email': 'marc.schiller@example.com',
#    'customer_address': '94105 Bahringer Oval Suite 178',
#    'customer_password': '67e9037197'},
#   {'customer_id': 8,
#    'payment_method': 'Direct Debit',
#    'customer_name': 'Ruthie',
#    'customer_phone': '(840)754-4148x20545',
#    'customer_email': 'elva.mccullough@example.org',
#    'customer_address': '5514 Ophelia Cliffs Apt. 266',
#    'customer_password': '280160b7b3'},
#   {'customer_id': 9,
#    'payment_method': 'Credit Card',
#    'customer_name': 'Donnie',
#    'customer_phone': '(030)521-0681x0191',
#    'customer_email': 'saul30@example.net',
#    'customer_address': '115 Farrell Squares Suite 599',
#    'customer_password': '22dc8bfaf5'},
#   {'customer_id': 10,
#    'payment_method': 'Direct Debit',
#    'customer_name': 'Shanel',
#    'customer_phone': '1-957-676-9414',
#    'customer_email': 'kheathcote@example.org',
#    'customer_address': '80569 Crona Path Suite 165',
#    'customer_password': 'd93857e0c2'},
#   {'customer_id': 11,
#    'payment_method': 'Direct Debit',
#    'customer_name': 'Osborne',
#    'customer_phone': '232.171.7032',
#    'customer_email': 'vpowlowski@example.net',
#    'customer_address': '509 Isabelle Route',
#    'customer_password': 'b00e35cc0a'},
#   {'customer_id': 12,
#    'payment_method': 'Direct Debit',
#    'customer_name': 'Kyle',
#    'customer_phone': '291-425-7193',
#    'customer_email': 'davis.rosamond@example.net',
#    'customer_address': '056 Ibrahim Path Suite 669',
#    'customer_password': '341f672c2c'},
#   {'customer_id': 13,
#    'payment_method': 'Credit Card',
#    'customer_name': 'Annabel',
#    'customer_phone': '100.220.3484',
#    'customer_email': 'yoshiko.balistreri@example.org',
#    'customer_address': '56955 Desmond Lake Apt. 120',
#    'customer_password': '9dc50bc5b6'},
#   {'customer_id': 14,
#    'payment_method': 'Direct Debit',
#    'customer_name': 'Geovanny',
#    'customer_phone': '205.496.0690x53058',
#    'customer_email': 'jesus.robel@example.org',
#    'customer_address': '0813 Carolina Bridge Suite 488',
#    'customer_password': '49f32173a2'},
#   {'customer_id': 15,
#    'payment_method': 'Direct Debit',
#    'customer_name': 'Mitchell',
#    'customer_phone': '698-327-5792',
#    'customer_email': 'princess75@example.com',
#    'customer_address': '6735 Daron Lane Apt. 271',
#    'customer_password': '791b1b3e64'}],
#  'Mailshot_Campaigns': [{'mailshot_id': 1,
#    'product_category': 'food',
#    'mailshot_name': 'US',
#    'mailshot_start_date': '02/15/2018',
#    'mailshot_end_date': '03/08/2018'},
#   {'mailshot_id': 2,
#    'product_category': 'clothes',
#    'mailshot_name': 'US',
#    'mailshot_start_date': '09/14/2017',
#    'mailshot_end_date': '03/15/2018'},
#   {'mailshot_id': 3,
#    'product_category': 'food',
#    'mailshot_name': 'FED',
#    'mailshot_start_date': '06/16/2017',
#    'mailshot_end_date': '03/13/2018'},
#   {'mailshot_id': 4,
#    'product_category': 'clothes',
#    'mailshot_name': 'USPS',
#    'mailshot_start_date': '09/27/2017',
#    'mailshot_end_date': '03/18/2018'},
#   {'mailshot_id': 5,
#    'product_category': 'food',
#    'mailshot_name': 'AL',
#    'mailshot_start_date': '05/20/2017',
#    'mailshot_end_date': '03/02/2018'},
#   {'mailshot_id': 6,
#    'product_category': 'clothes',
#    'mailshot_name': 'FED',
#    'mailshot_start_date': '10/23/2017',
#    'mailshot_end_date': '03/03/2018'},
#   {'mailshot_id': 7,
#    'product_category': 'food',
#    'mailshot_name': 'FED',
#    'mailshot_start_date': '11/25/2017',
#    'mailshot_end_date': '03/05/2018'},
#   {'mailshot_id': 8,
#    'product_category': 'clothes',
#    'mailshot_name': 'AL',
#    'mailshot_start_date': '10/22/2017',
#    'mailshot_end_date': '03/01/2018'},
#   {'mailshot_id': 9,
#    'product_category': 'food',
#    'mailshot_name': 'US',
#    'mailshot_start_date': '11/12/2017',
#    'mailshot_end_date': '02/27/2018'},
#   {'mailshot_id': 10,
#    'product_category': 'clothes',
#    'mailshot_name': 'USPS',
#    'mailshot_start_date': '01/14/2018',
#    'mailshot_end_date': '03/19/2018'},
#   {'mailshot_id': 11,
#    'product_category': 'food',
#    'mailshot_name': 'US',
#    'mailshot_start_date': '12/13/2017',
#    'mailshot_end_date': '03/24/2018'},
#   {'mailshot_id': 12,
#    'product_category': 'clothes',
#    'mailshot_name': 'USPS',
#    'mailshot_start_date': '01/20/2018',
#    'mailshot_end_date': '03/23/2018'},
#   {'mailshot_id': 13,
#    'product_category': 'food',
#    'mailshot_name': 'AL',
#    'mailshot_start_date': '05/08/2017',
#    'mailshot_end_date': '03/12/2018'},
#   {'mailshot_id': 14,
#    'product_category': 'clothes',
#    'mailshot_name': 'AL',
#    'mailshot_start_date': '06/11/2017',
#    'mailshot_end_date': '03/23/2018'},
#   {'mailshot_id': 15,
#    'product_category': 'food',
#    'mailshot_name': 'FED',
#    'mailshot_start_date': '11/29/2017',
#    'mailshot_end_date': '03/17/2018'},
#   {'mailshot_id': 16,
#    'product_category': 'clothes',
#    'mailshot_name': 'US',
#    'mailshot_start_date': '11/02/2017',
#    'mailshot_end_date': '03/02/2018'},
#   {'mailshot_id': 17,
#    'product_category': 'food',
#    'mailshot_name': 'FED',
#    'mailshot_start_date': '02/04/2018',
#    'mailshot_end_date': '02/26/2018'},
#   {'mailshot_id': 18,
#    'product_category': 'clothes',
#    'mailshot_name': 'USPS',
#    'mailshot_start_date': '12/08/2017',
#    'mailshot_end_date': '03/20/2018'},
#   {'mailshot_id': 19,
#    'product_category': 'food',
#    'mailshot_name': 'US',
#    'mailshot_start_date': '06/25/2017',
#    'mailshot_end_date': '03/15/2018'},
#   {'mailshot_id': 20,
#    'product_category': 'food',
#    'mailshot_name': 'US',
#    'mailshot_start_date': '11/15/2017',
#    'mailshot_end_date': '03/15/2018'}],
#  'Customer_Addresses': [{'customer_id': 15,
#    'premise_id': 1,
#    'date_address_from': '08/23/1992',
#    'address_type_code': 'Billing',
#    'date_address_to': '02/28/2018'},
#   {'customer_id': 2,
#    'premise_id': 2,
#    'date_address_from': '02/23/2010',
#    'address_type_code': 'Billing',
#    'date_address_to': '03/15/2018'},
#   {'customer_id': 1,
#    'premise_id': 1,
#    'date_address_from': '12/24/1975',
#    'address_type_code': 'Shipping',
#    'date_address_to': '03/08/2018'},
#   {'customer_id': 3,
#    'premise_id': 2,
#    'date_address_from': '03/26/1995',
#    'address_type_code': 'Shipping',
#    'date_address_to': '02/27/2018'},
#   {'customer_id': 7,
#    'premise_id': 1,
#    'date_address_from': '05/14/1929',
#    'address_type_code': 'Billing',
#    'date_address_to': '03/16/2018'},
#   {'customer_id': 8,
#    'premise_id': 4,
#    'date_address_from': '01/15/1939',
#    'address_type_code': 'Shipping',
#    'date_address_to': '03/13/2018'},
#   {'customer_id': 5,
#    'premise_id': 5,
#    'date_address_from': '03/24/1931',
#    'address_type_code': 'Shipping',
#    'date_address_to': '03/05/2018'},
#   {'customer_id': 11,
#    'premise_id': 6,
#    'date_address_from': '04/23/1975',
#    'address_type_code': 'Billing',
#    'date_address_to': '03/04/2018'},
#   {'customer_id': 11,
#    'premise_id': 3,
#    'date_address_from': '08/18/1920',
#    'address_type_code': 'Shipping',
#    'date_address_to': '03/22/2018'},
#   {'customer_id': 11,
#    'premise_id': 5,
#    'date_address_from': '07/31/1960',
#    'address_type_code': 'Shipping',
#    'date_address_to': '03/09/2018'},
#   {'customer_id': 13,
#    'premise_id': 6,
#    'date_address_from': '12/19/1990',
#    'address_type_code': 'Billing',
#    'date_address_to': '03/24/2018'},
#   {'customer_id': 4,
#    'premise_id': 8,
#    'date_address_from': '03/18/1985',
#    'address_type_code': 'Shipping',
#    'date_address_to': '02/27/2018'},
#   {'customer_id': 10,
#    'premise_id': 10,
#    'date_address_from': '06/06/1972',
#    'address_type_code': 'Billing',
#    'date_address_to': '03/08/2018'},
#   {'customer_id': 8,
#    'premise_id': 12,
#    'date_address_from': '06/16/1984',
#    'address_type_code': 'Billing',
#    'date_address_to': '03/05/2018'},
#   {'customer_id': 3,
#    'premise_id': 14,
#    'date_address_from': '02/01/2002',
#    'address_type_code': 'Billing',
#    'date_address_to': '03/16/2018'}],
#  'Customer_Orders': [{'order_id': 1,
#    'customer_id': 2,
#    'order_status_code': 'Cancelled',
#    'shipping_method_code': 'Unspecified',
#    'order_placed_datetime': '06/15/2015',
#    'order_delivered_datetime': '03/20/2018',
#    'order_shipping_charges': '85.79'},
#   {'order_id': 2,
#    'customer_id': 8,
#    'order_status_code': 'Cancelled',
#    'shipping_method_code': 'Unspecified',
#    'order_placed_datetime': '07/05/2009',
#    'order_delivered_datetime': '03/20/2018',
#    'order_shipping_charges': '98.4'},
#   {'order_id': 3,
#    'customer_id': 9,
#    'order_status_code': 'Cancelled',
#    'shipping_method_code': 'FedEx',
#    'order_placed_datetime': '11/15/2008',
#    'order_delivered_datetime': '03/20/2018',
#    'order_shipping_charges': '36.87'},
#   {'order_id': 4,
#    'customer_id': 1,
#    'order_status_code': 'Delivered',
#    'shipping_method_code': 'UPS',
#    'order_placed_datetime': '10/23/2008',
#    'order_delivered_datetime': '03/20/2018',
#    'order_shipping_charges': '98.73'},
#   {'order_id': 5,
#    'customer_id': 7,
#    'order_status_code': 'Paid',
#    'shipping_method_code': 'FedEx',
#    'order_placed_datetime': '05/28/2017',
#    'order_delivered_datetime': '03/20/2018',
#    'order_shipping_charges': '35.63'},
#   {'order_id': 6,
#    'customer_id': 2,
#    'order_status_code': 'Cancelled',
#    'shipping_method_code': 'Unspecified',
#    'order_placed_datetime': '06/24/2014',
#    'order_delivered_datetime': '03/20/2018',
#    'order_shipping_charges': '99.26'},
#   {'order_id': 7,
#    'customer_id': 15,
#    'order_status_code': 'Cancelled',
#    'shipping_method_code': 'FedEx',
#    'order_placed_datetime': '08/28/2014',
#    'order_delivered_datetime': '03/20/2018',
#    'order_shipping_charges': '26.56'},
#   {'order_id': 8,
#    'customer_id': 2,
#    'order_status_code': 'Delivered',
#    'shipping_method_code': 'Unspecified',
#    'order_placed_datetime': '06/05/2012',
#    'order_delivered_datetime': '03/20/2018',
#    'order_shipping_charges': '77.32'},
#   {'order_id': 9,
#    'customer_id': 1,
#    'order_status_code': 'Cancelled',
#    'shipping_method_code': 'FedEx',
#    'order_placed_datetime': '05/30/2009',
#    'order_delivered_datetime': '03/20/2018',
#    'order_shipping_charges': '57.36'},
#   {'order_id': 10,
#    'customer_id': 14,
#    'order_status_code': 'Paid',
#    'shipping_method_code': 'Unspecified',
#    'order_placed_datetime': '08/29/2013',
#    'order_delivered_datetime': '03/20/2018',
#    'order_shipping_charges': '33.58'},
#   {'order_id': 11,
#    'customer_id': 1,
#    'order_status_code': 'Paid',
#    'shipping_method_code': 'Unspecified',
#    'order_placed_datetime': '12/29/2015',
#    'order_delivered_datetime': '03/20/2018',
#    'order_shipping_charges': '22.84'},
#   {'order_id': 12,
#    'customer_id': 12,
#    'order_status_code': 'Cancelled',
#    'shipping_method_code': 'Unspecified',
#    'order_placed_datetime': '10/20/2016',
#    'order_delivered_datetime': '03/20/2018',
#    'order_shipping_charges': '21.24'},
#   {'order_id': 13,
#    'customer_id': 12,
#    'order_status_code': 'Paid',
#    'shipping_method_code': 'FedEx',
#    'order_placed_datetime': '06/16/2013',
#    'order_delivered_datetime': '03/20/2018',
#    'order_shipping_charges': '31.33'},
#   {'order_id': 14,
#    'customer_id': 14,
#    'order_status_code': 'Paid',
#    'shipping_method_code': 'UPS',
#    'order_placed_datetime': '04/29/2010',
#    'order_delivered_datetime': '03/20/2018',
#    'order_shipping_charges': '46.4'},
#   {'order_id': 15,
#    'customer_id': 5,
#    'order_status_code': 'Delivered',
#    'shipping_method_code': 'FedEx',
#    'order_placed_datetime': '01/18/2009',
#    'order_delivered_datetime': '03/20/2018',
#    'order_shipping_charges': '74.28'}],
#  'Mailshot_Customers': [{'mailshot_id': 4,
#    'customer_id': 3,
#    'outcome_code': 'Order',
#    'mailshot_customer_date': '03/15/2018'},
#   {'mailshot_id': 10,
#    'customer_id': 1,
#    'outcome_code': 'No Response',
#    'mailshot_customer_date': '03/04/2018'},
#   {'mailshot_id': 15,
#    'customer_id': 9,
#    'outcome_code': 'No Response',
#    'mailshot_customer_date': '03/11/2018'},
#   {'mailshot_id': 20,
#    'customer_id': 11,
#    'outcome_code': 'Order',
#    'mailshot_customer_date': '03/01/2018'},
#   {'mailshot_id': 7,
#    'customer_id': 1,
#    'outcome_code': 'Order',
#    'mailshot_customer_date': '03/13/2018'},
#   {'mailshot_id': 10,
#    'customer_id': 4,
#    'outcome_code': 'No Response',
#    'mailshot_customer_date': '03/15/2018'},
#   {'mailshot_id': 15,
#    'customer_id': 6,
#    'outcome_code': 'Order',
#    'mailshot_customer_date': '03/06/2018'},
#   {'mailshot_id': 10,
#    'customer_id': 13,
#    'outcome_code': 'Order',
#    'mailshot_customer_date': '02/26/2018'},
#   {'mailshot_id': 15,
#    'customer_id': 13,
#    'outcome_code': 'Order',
#    'mailshot_customer_date': '03/07/2018'},
#   {'mailshot_id': 17,
#    'customer_id': 11,
#    'outcome_code': 'Order',
#    'mailshot_customer_date': '03/05/2018'},
#   {'mailshot_id': 18,
#    'customer_id': 14,
#    'outcome_code': 'Order',
#    'mailshot_customer_date': '03/14/2018'},
#   {'mailshot_id': 15,
#    'customer_id': 6,
#    'outcome_code': 'Order',
#    'mailshot_customer_date': '02/27/2018'},
#   {'mailshot_id': 18,
#    'customer_id': 2,
#    'outcome_code': 'Order',
#    'mailshot_customer_date': '03/20/2018'},
#   {'mailshot_id': 7,
#    'customer_id': 1,
#    'outcome_code': 'No Response',
#    'mailshot_customer_date': '03/03/2018'},
#   {'mailshot_id': 6,
#    'customer_id': 6,
#    'outcome_code': 'No Response',
#    'mailshot_customer_date': '03/05/2018'}],
#  'Order_Items': [{'item_id': 1,
#    'order_item_status_code': 'Delivered',
#    'order_id': 10,
#    'product_id': 13,
#    'item_status_code': 'good',
#    'item_delivered_datetime': '02/25/2018',
#    'item_order_quantity': '6'},
#   {'item_id': 2,
#    'order_item_status_code': 'Paid',
#    'order_id': 6,
#    'product_id': 7,
#    'item_status_code': 'good',
#    'item_delivered_datetime': '02/27/2018',
#    'item_order_quantity': '7'},
#   {'item_id': 3,
#    'order_item_status_code': 'Cancelled',
#    'order_id': 8,
#    'product_id': 1,
#    'item_status_code': 'good',
#    'item_delivered_datetime': '03/16/2018',
#    'item_order_quantity': '4'},
#   {'item_id': 4,
#    'order_item_status_code': 'Cancelled',
#    'order_id': 13,
#    'product_id': 11,
#    'item_status_code': 'good',
#    'item_delivered_datetime': '03/04/2018',
#    'item_order_quantity': '3'},
#   {'item_id': 5,
#    'order_item_status_code': 'Paid',
#    'order_id': 11,
#    'product_id': 5,
#    'item_status_code': 'good',
#    'item_delivered_datetime': '03/07/2018',
#    'item_order_quantity': '6'},
#   {'item_id': 6,
#    'order_item_status_code': 'Delivered',
#    'order_id': 6,
#    'product_id': 10,
#    'item_status_code': 'good',
#    'item_delivered_datetime': '03/03/2018',
#    'item_order_quantity': '5'},
#   {'item_id': 7,
#    'order_item_status_code': 'Delivered',
#    'order_id': 7,
#    'product_id': 14,
#    'item_status_code': 'good',
#    'item_delivered_datetime': '03/04/2018',
#    'item_order_quantity': '6'},
#   {'item_id': 8,
#    'order_item_status_code': 'Delivered',
#    'order_id': 2,
#    'product_id': 5,
#    'item_status_code': 'good',
#    'item_delivered_datetime': '03/05/2018',
#    'item_order_quantity': '4'},
#   {'item_id': 9,
#    'order_item_status_code': 'Delivered',
#    'order_id': 6,
#    'product_id': 6,
#    'item_status_code': 'good',
#    'item_delivered_datetime': '03/22/2018',
#    'item_order_quantity': '6'},
#   {'item_id': 10,
#    'order_item_status_code': 'Cancelled',
#    'order_id': 7,
#    'product_id': 9,
#    'item_status_code': 'good',
#    'item_delivered_datetime': '03/03/2018',
#    'item_order_quantity': '2'},
#   {'item_id': 11,
#    'order_item_status_code': 'Paid',
#    'order_id': 15,
#    'product_id': 3,
#    'item_status_code': 'good',
#    'item_delivered_datetime': '03/12/2018',
#    'item_order_quantity': '1'},
#   {'item_id': 12,
#    'order_item_status_code': 'Delivered',
#    'order_id': 11,
#    'product_id': 9,
#    'item_status_code': 'good',
#    'item_delivered_datetime': '03/03/2018',
#    'item_order_quantity': '5'},
#   {'item_id': 13,
#    'order_item_status_code': 'Paid',
#    'order_id': 14,
#    'product_id': 1,
#    'item_status_code': 'good',
#    'item_delivered_datetime': '03/07/2018',
#    'item_order_quantity': '5'},
#   {'item_id': 14,
#    'order_item_status_code': 'Paid',
#    'order_id': 15,
#    'product_id': 13,
#    'item_status_code': 'good',
#    'item_delivered_datetime': '03/17/2018',
#    'item_order_quantity': '9'},
#   {'item_id': 15,
#    'order_item_status_code': 'Paid',
#    'order_id': 14,
#    'product_id': 9,
#    'item_status_code': 'good',
#    'item_delivered_datetime': '03/05/2018',
#    'item_order_quantity': '4'}]}

# %% [markdown]
# #### Ejercicio 2. Consultas Básicas.
#
# - 2.1. Encuentra todos los locales que sean de tipo "Warehouse".

# %% [markdown]
# - 2.2. Obtén todas las categorías de productos distintas.
#
# - 2.3. Encuentra todos los productos que no estén en la categoría "Electronics".
#
# - 2.4. Encuentra todos los productos cuyo product_id sea mayor a 5.
#
# - 2.5. Encuentra todos los locales con premise_id menor o igual a 3.
#
# - 2.6. Encuentra todos los locales que sean de tipo "Warehouse" o tengan premise_id igual a 7.
#
# - 2.7. Encuentra todos los clientes cuyo método de pago no sea "Direct Debit".
#
# - 2.8. Encuentra todos los locales que tengan un campo premise_details.
#
# - 2.9. Encuentra todos los productos cuyo product_id esté en la lista [1, 3, 5].
#
# - 2.10. Encuentra todos los clientes cuyo correo electrónico contenga ".com".
#
# #### Ejercicio 3. Proyecciones y ordenamiento
#
#
# - 3.1. Encuentra todos los locales mostrando solo premise_id y premises_type.
#
# - 3.2. Encuentra todos los productos ordenados por product_name en orden ascendente.
#
# - 3.3. Encuentra los primeros 5 clientes.
#
# - 3.4. Encuentra los siguientes 5 clientes después de los primeros 5.
#
# - 3.5. Proyecta solo el product_name y la product_category de todos los productos.
#
# #### Ejercicio 4. Consultas Avanzadas.
#
# - 4.1. Encuentra todas las campañas de marketing en la categoría "food".
#
# - 4.2. Agrupa los productos por categoría y cuenta el número de productos en cada categoría.
#
# - 4.3. Realiza una búsqueda cruzada para encontrar los detalles de los locales asociados con cada dirección de cliente.
#
# - 4.4. Encuentra todas las campañas de marketing que comenzaron en el año 2021.
#
# - 4.5. Encuentra todas las categorías de productos que tienen al menos un producto cuyo product_id sea mayor a 10 y el nombre del producto contenga la letra 'a'.
#
# - 4.6. Encuentra todos los clientes cuyo método de pago sea "Credit Card" y cuya dirección de correo electrónico contenga "example.com". Proyecta solo el nombre del cliente y el correo electrónico.
#
# - 4.7. Proyecta solo el customer_id y address_type_code de todas las direcciones de clientes registradas después del "01/01/2021" y cuenta cuántas direcciones hay
